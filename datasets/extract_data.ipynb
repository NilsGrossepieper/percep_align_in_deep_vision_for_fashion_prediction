# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !bash /content/drive/MyDrive/perceptual-vits-fashion-forecasting/datasets/extract_visuelle.sh
# !bash /content/drive/MyDrive/perceptual-vits-fashion-forecasting/datasets/extract_nights.sh
! bash /content/drive/MyDrive/perceptual-vits-fashion-forecasting/datasets/extract_fashion_triplets.sh
# Out:
# Extraction complete! Files are in: /content/drive/MyDrive/perceptual-vits-fashion-forecasting/datasets/
